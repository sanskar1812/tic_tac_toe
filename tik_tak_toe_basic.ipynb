# %% [markdown]
# ### print out a board

# %%
from IPython.display import clear_output
def display_board(board):
    
    clear_output()
    print('   |   |')
    print(' ' + board[7] + ' | ' + board[8] + ' | ' + board[9])
    print('   |   |')
    print('-----------')
    print('   |   |')
    print(' ' + board[4] + ' | ' + board[5] + ' | ' + board[6])
    print('   |   |')
    
    print('-----------')
    print('   |   |')
    print(' ' + board[1] + ' | ' + board[2] + ' | ' + board[3])
    print('   |   |')

# %%
print("Welcome to the game:")

current_board=[' ']*10
marker=' '
l=[]

display_board(current_board)

while not(marker=='O' or marker=='X'):
    marker=input('Player 1: Do you want to choose X or O : ').upper()
    
    if(marker=='X'):
        l.append('X')
        l.append('O')
    elif(marker=='O'):
        l.append('O')
        l.append('X')
        
import random
if random.randint(0, 1) == 0:
    player='Player1'
    print(player+" Will go first, his symbol is "+l[0])
else:
    player='Player2'
    print(player+" Will go first, his symbol is "+l[1])

print("---------------")

for i in range(1,10):
    
    print('Player1 : '+l[0])
    print('Player2 : '+l[1])
    position = ' '
    print(player+": CHANCE")
        
    while position not in '1 2 3 4 5 6 7 8 9'.split():
        position = input('Choose your next position: (1-9) ')    
        
        if(player=='Player1'):
            current_board[int(position)]=l[0]
            player='Player2'
        else:
            current_board[int(position)]=l[1]
            player='Player1'

        display_board(current_board)
    
    
    
    
if(current_board[1]==current_board[2]==current_board[3]):
    x=current_board[1]
    if(x==l[0]):
        print("Player 1 won the game")
    else:
        print("Player 2 won the game")

elif(current_board[4]==current_board[5]==current_board[6]):
    x=current_board[4]
    if(x==l[0]):
        print("Player 1 won the game")
    else:
        print("Player 2 won the game")

elif(current_board[7]==current_board[8]==current_board[9]):
    x=current_board[7]
    if(x==l[0]):
        print("Player 1 won the game")
    else:
        print("Player 2 won the game")
   
elif(current_board[1]==current_board[5]==current_board[9]):
    x=current_board[1]
    if(x==l[0]):
        print("Player 1 won the game")
    else:
        print("Player 2 won the game")
   
elif(current_board[1]==current_board[4]==current_board[7]):
    x=current_board[1]
    if(x==l[0]):
        print("Player 1 won the game")
    else:
        print("Player 2 won the game")
        
        
elif(current_board[2]==current_board[5]==current_board[8]):
    x=current_board[2]
    if(x==l[0]):
        print("Player 1 won the game")
    else:
        print("Player 2 won the game")
        
        
elif(current_board[3]==current_board[6]==current_board[9]):
    x=current_board[3]
    if(x==l[0]):
        print("Player 1 won the game")
    else:
        print("Player 2 won the game")
        
elif(current_board[3]==current_board[5]==current_board[7]):
    x=current_board[3]
    if(x==l[0]):
        print("Player 1 won the game")
    else:
        print("Player 2 won the game")
 
else:
    print("DRAW")
# Out:
#    |   |
#  X | O | O
#    |   |
# -----------
#    |   |
#  X | O | X
#    |   |
# -----------
#    |   |
#  O | X | O
#    |   |
# Player 2 won the game

# %% [markdown]
# # Hope, you enjoyed the game
